# %%
import googlemaps
from datetime import datetime
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
gmaps = googlemaps.Client(key=os.getenv('API_KEY'))

# %%
geocode_result = gmaps.places('starbucks palo alto')
geocode_result
# Out:
# {'html_attributions': [],
#  'results': [{'formatted_address': '376 University Ave, Palo Alto, CA 94301, United States',
#    'geometry': {'location': {'lat': 37.446791, 'lng': -122.160561},
#     'viewport': {'northeast': {'lat': 37.44816977989272,
#       'lng': -122.1592721201073},
#      'southwest': {'lat': 37.44547012010728, 'lng': -122.1619717798928}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': 'f9684a5bbb5338e374a555fbb2683b8cbc0c372c',
#    'name': 'Starbucks',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104609939326496492903/photos">Mustafa GOKDOGAN</a>'],
#      'photo_reference': 'CmRaAAAAIiqSrb6oBaC-0ArmMv_giV-_-ra25oh4qrP54X940fvoH2AP5_PY9nZnj7uXGn4B8CSBDhPZlj8NaWCTo1KquN2WSfgPHBdUMZHRTu2fQbMOsPu1reJkeAGzVqAuVTjmEhCUdzvHEl0aY5UNL4-Wm_NiGhTZ78PwRyPDvqlxH3OzCRSN3eoGYw',
#      'width': 3024}],
#    'place_id': 'ChIJg5JmqDm7j4ARxxy2NX7uuIQ',
#    'plus_code': {'compound_code': 'CRWQ+PQ Palo Alto, California, United States',
#     'global_code': '849VCRWQ+PQ'},
#    'price_level': 2,
#    'rating': 4.1,
#    'reference': 'ChIJg5JmqDm7j4ARxxy2NX7uuIQ',
#    'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 469},
#   {'formatted_address': '2000 El Camino Real, Palo Alto, CA 94306, United States',
#    'geometry': {'location': {'lat': 37.427381, 'lng': -122.149213},
#     'viewport': {'northeast': {'lat': 37.42872647989272,
#       'lng': -122.1478205701073},
#      'southwest': {'lat': 37.42602682010727, 'lng': -122.1505202298927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': 'dc76f5716b8fd67e7d76ec1115728a7a8e04f82f',
#    'name': 'Starbucks',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110627053977800080922/photos">simon lechot</a>'],
#      'photo_reference': 'CmRaAAAA2jvAfkjPddn9ucH2i759VnXRu8Yi7SfkBTKgRK64aPmCQ5LSmfF6liMRO0Jj1fEa8SkGCttd6SKCE4qfytoC38353-0DHiUXQ6xt4E3kMl7oyFEAh-N7crhhcbl29LN3EhDl3xn-QRvAjiWvXbiP6ugZGhQv9uluh9B1QQ2ltR0nxxmylGdTfw',
#      'width': 3024}],
#    'place_id': 'ChIJsUowmuW6j4ARncdA5qucqUk',
#    'plus_code': {'compound_code': 'CVG2+X8 Palo Alto, California, United States',
#     'global_code': '849VCVG2+X8'},
#    'price_level': 2,
#    'rating': 3.9,
#    'reference': 'ChIJsUowmuW6j4ARncdA5qucqUk',
#    'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 329},
#   {'formatted_address': '3885 El Camino Real, Palo Alto, CA 94306, United States',
#    'geometry': {'location': {'lat': 37.417361, 'lng': -122.130601},
#     'viewport': {'northeast': {'lat': 37.41865157989272,
#       'lng': -122.1291128201073},
#      'southwest': {'lat': 37.41595192010727, 'lng': -122.1318124798927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': '7e7dbef37faf983695c5496bf01059e63bd65567',
#    'name': 'Starbucks',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107971697972965735589/photos">Tricia C</a>'],
#      'photo_reference': 'CmRaAAAATAIxeykbMoXTn5D7yEZHIimjz86BZ0kqOZcdHs8TnR4eZDCTBkvn9fRggEuWZRd1mTYAJPUr9cIPqsx0_QntAC2NgjqbMY3N2uI8r2iqOpYn5UfFLAUedsEYt5fQdtkWEhDA1DVPRehIJ5jViP0Ms1tQGhRmU1tSJo4SMXeTEGSUgr-mSAu-tQ',
#      'width': 2992}],
#    'place_id': 'ChIJY4beF2O6j4ARW2fH2_0wp0g',
#    'plus_code': {'compound_code': 'CV89+WQ Palo Alto, California, United States',
#     'global_code': '849VCV89+WQ'},
#    'price_level': 2,
#    'rating': 4.1,
#    'reference': 'ChIJY4beF2O6j4ARW2fH2_0wp0g',
#    'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 331},
#   {'formatted_address': '2190 W Bayshore Rd Ste. 180, Palo Alto, CA 94303, United States',
#    'geometry': {'location': {'lat': 37.447958, 'lng': -122.126258},
#     'viewport': {'northeast': {'lat': 37.44922002989272,
#       'lng': -122.1248221201073},
#      'southwest': {'lat': 37.44652037010728, 'lng': -122.1275217798927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': 'a67a299856adeccc7696a2ecd846d3605d2d9f7b',
#    'name': 'Starbucks',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109665942099333580315/photos">andy hsu</a>'],
#      'photo_reference': 'CmRaAAAAbr5LemLLLfjpbcf-D9aK7J6wTmytICD-U7vmUUF3l0MvuROTRlCe_z03lLw19u-zRBwkkr2P0Tz1GKmcDhJNPDmCivP4chLGG6DoPEPLVl024_1Bq4xSovMmG95CM_DkEhCMYEyx-ARu0yoRbHIHDWvFGhTb1OAcN9tPRvb1NjCulxfpLn8h7w',
#      'width': 3024}],
#    'place_id': 'ChIJpWutqqm7j4ARNnvOAeRP-5U',
#    'plus_code': {'compound_code': 'CVXF+5F Palo Alto, California, United States',
#     'global_code': '849VCVXF+5F'},
#    'price_level': 2,
#    'rating': 4.1,
#    'reference': 'ChIJpWutqqm7j4ARNnvOAeRP-5U',
#    'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 247},
#   {'formatted_address': '361 California Ave, Palo Alto, CA 94306, United States',
#    'geometry': {'location': {'lat': 37.426867, 'lng': -122.144091},
#     'viewport': {'northeast': {'lat': 37.42825412989272,
#       'lng': -122.1428284201073},
#      'southwest': {'lat': 37.42555447010727, 'lng': -122.1455280798927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': '93606c439ca5804040ba07d8d4c162566a052c27',
#    'name': 'Starbucks',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 289,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114056203097317877718/photos">Starbucks</a>'],
#      'photo_reference': 'CmRaAAAAlwpcWlW18Fb43oHschSM9joDZ1PN87-F6EfZmdPzoBjv4RJ8uB-CJWBiVk8THJ4uqqhPXC3z98JfkumGPYoHtQBeFAzk5BPgyNT0sksPoJGDtTe5xxFW22MNsKxUkqiiEhB5ffgiqTSzGLdu-Udoc56UGhRF-pL4zASsRK9C9uoC-LneQuRHsw',
#      'width': 512}],
#    'place_id': 'ChIJsUowmuW6j4ARQq7ht0-RXP8',
#    'plus_code': {'compound_code': 'CVG4+P9 Palo Alto, California, United States',
#     'global_code': '849VCVG4+P9'},
#    'price_level': 2,
#    'rating': 4,
#    'reference': 'ChIJsUowmuW6j4ARQq7ht0-RXP8',
#    'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 291},
#   {'formatted_address': '79 Stanford Shopping Center, Palo Alto, CA 94304, United States',
#    'geometry': {'location': {'lat': 37.443643, 'lng': -122.171738},
#     'viewport': {'northeast': {'lat': 37.44486812989273,
#       'lng': -122.1706817701073},
#      'southwest': {'lat': 37.44216847010728, 'lng': -122.1733814298927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': '2e6d55cdf328e443a4745b89691733acd89a3e9e',
#    'name': 'Starbucks',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104709963464421581701/photos">Wendi Rieb</a>'],
#      'photo_reference': 'CmRaAAAAwAJZmEDghm79DmO4at3ZgotZLsEdsiXaHaG_8Evl4RPYhwzmXWpUG8z8qZdFlyMLOlpavCzahqp_aHF2euPlDcI-IkwqUIN84FCGJIs95rEt4aABzHZmnwzAPOIPXN1FEhDuQyzFQs69BFXCzdg4cxQdGhSawEmX81Pi3PHop2tI-Mp-h74BYw',
#      'width': 4032}],
#    'place_id': 'ChIJafo-_zS7j4AR8mEOg02EaUw',
#    'plus_code': {'compound_code': 'CRVH+F8 Palo Alto, California, United States',
#     'global_code': '849VCRVH+F8'},
#    'price_level': 2,
#    'rating': 4,
#    'reference': 'ChIJafo-_zS7j4AR8mEOg02EaUw',
#    'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 244},
#   {'formatted_address': '1745 E Bayshore Rd, Palo Alto, CA 94303, United States',
#    'geometry': {'location': {'lat': 37.461558, 'lng': -122.137201},
#     'viewport': {'northeast': {'lat': 37.46285252989272,
#       'lng': -122.1358499201072},
#      'southwest': {'lat': 37.46015287010728, 'lng': -122.1385495798927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': '0e8e750f13acc7a1a1e86d9b39282f06f5ff5f48',
#    'name': 'Starbucks',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3036,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100125785501541652628/photos">Shiu N</a>'],
#      'photo_reference': 'CmRaAAAAskp4pudVR09nemov4DjlRThqdxNvDykamWUzlnehW3IhLWXap1w4GFB4jDHYZPvxWmQgpOMRxXKGxMDnskn3T_Miw40eEnffcRgOxUYQ5bEyzVW5tospKEyvI6LLC897EhCfNMl-zS720tnV5D46avSfGhQlTEUpx_QMkBe8TH8n9MmPzTfkAA',
#      'width': 4048}],
#    'place_id': 'ChIJp2p2fXG7j4ARXtLSSvO3hhc',
#    'plus_code': {'compound_code': 'FV67+J4 Palo Alto, California, United States',
#     'global_code': '849VFV67+J4'},
#    'price_level': 2,
#    'rating': 4,
#    'reference': 'ChIJp2p2fXG7j4ARXtLSSvO3hhc',
#    'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 209},
#   {'formatted_address': '1775 E Bayshore Rd E, Palo Alto, CA 94303, United States',
#    'geometry': {'location': {'lat': 37.4599286, 'lng': -122.1359578},
#     'viewport': {'northeast': {'lat': 37.46127722989272,
#       'lng': -122.1346717201073},
#      'southwest': {'lat': 37.45857757010728, 'lng': -122.1373713798928}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': '927fe264419b0dc2b27bbc3e7be089fd9330a1a5',
#    'name': 'Starbucks',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1960,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117400780974343626020/photos">Alina Squeak</a>'],
#      'photo_reference': 'CmRaAAAAFUwoWJjwk8AVnSrx4I4lKS7TpZvjk6-nVIGi8Ear_D8_Bk4JIr_ZXCaDKOg16T-BiKOyU8gWi8aKJxYsAxr6aHFDuNQqRCrjp72utquoocyCc0xB48q-6pE3YkPGeoVREhA54QSo7vnWNWIYIj3qETPoGhSnWz_XbWjlZeAoovRtgTcSVrtJzw',
#      'width': 4032}],
#    'place_id': 'ChIJqaONeHO7j4ARuJHgViEaXrQ',
#    'plus_code': {'compound_code': 'FV57+XJ Palo Alto, California, United States',
#     'global_code': '849VFV57+XJ'},
#    'price_level': 2,
#    'rating': 3.8,
#    'reference': 'ChIJqaONeHO7j4ARuJHgViEaXrQ',
#    'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 11},
#   {'formatted_address': '565 San Antonio Rd #28, Mountain View, CA 94040, United States',
#    'geometry': {'location': {'lat': 37.402755, 'lng': -122.112379},
#     'viewport': {'northeast': {'lat': 37.40400847989272,
#       'lng': -122.1110988701073},
#      'southwest': {'lat': 37.40130882010727, 'lng': -122.1137985298927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': '60b221a456c87dc0c8000f4ec47d845599c3e5da',
#    'name': 'Starbucks',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101452311751271433713/photos">Volodymyr Ivanov</a>'],
#      'photo_reference': 'CmRaAAAAq7KT6mydJrVxLB3eGa2jiZ5ncYBMRz4ThmQB7fOusv0XavOALQ1J98FaSBC4iCaOoWb3M1LNl_giDIQSCGA57YOY7UadODpCLz-1M6hh9HpjCklW7fqPhA35xgDh8SqNEhChThX5Y3tvz2rqGljRxGhpGhQgy9ahX4I1uJ_7sMrhJKgqO2hj0A',
#      'width': 3024}],
#    'place_id': 'ChIJpxe1H5ywj4ARzPZ7VLhUqHo',
#    'plus_code': {'compound_code': 'CV3Q+42 Mountain View, California, United States',
#     'global_code': '849VCV3Q+42'},
#    'price_level': 2,
#    'rating': 4.2,
#    'reference': 'ChIJpxe1H5ywj4ARzPZ7VLhUqHo',
#    'types': ['cafe',
#     'bar',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 268},
#   {'formatted_address': '2410 Charleston Rd, Mountain View, CA 94043, United States',
#    'geometry': {'location': {'lat': 37.4218, 'lng': -122.096419},
#     'viewport': {'northeast': {'lat': 37.42320707989273,
#       'lng': -122.0949763701072},
#      'southwest': {'lat': 37.42050742010728, 'lng': -122.0976760298927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': 'f411ccab555dd1236ea91285b29ae1acf943225e',
#    'name': 'Starbucks',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1280,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116105641729894793717/photos">Abhey Sarran</a>'],
#      'photo_reference': 'CmRaAAAAwQzUSFAb8i1B09l431aouBwAZDyX08bF5v4s6UdNeFmdwrixIINNloRtEszQv9z9Kqe-zL1XMdpWk11gFO1Okhs8LoWOXubXEzNiq6fCKjGmuZ5sRQDEgWqKuDcz4TdXEhDmcLDQw_XJ8iCdUy29aQXXGhSLRtBK-3T-IKBgwB5S35ml5lnySw',
#      'width': 960}],
#    'place_id': 'ChIJT_9zPBC6j4ARm2Fu2gYDC0k',
#    'plus_code': {'compound_code': 'CWC3+PC Mountain View, California, United States',
#     'global_code': '849VCWC3+PC'},
#    'price_level': 2,
#    'rating': 4.2,
#    'reference': 'ChIJT_9zPBC6j4ARm2Fu2gYDC0k',
#    'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 268},
#   {'formatted_address': '459 Lagunita Dr, Stanford, CA 94305, United States',
#    'geometry': {'location': {'lat': 37.424345, 'lng': -122.170762},
#     'viewport': {'northeast': {'lat': 37.42569482989271,
#       'lng': -122.1694121701073},
#      'southwest': {'lat': 37.42299517010727, 'lng': -122.1721118298927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': 'a93419d2648e5d738e2ff46ca1719948992774b7',
#    'name': 'Starbucks',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4048,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103058987955585864302/photos">Thomas Galipean</a>'],
#      'photo_reference': 'CmRaAAAA6ZC7KwnfSrcxm2KMG0VZXlWRgB3GF1dLQHo24WASY-lwN9St4Z6U0yAtIwY-bgubOHjzfLJbki6SLT2RqSWYsgjun5BS-ubFF4ire_JYUe7PvEIenr0wdNVKX0bFcU0dEhDQf3FuCX1LsHy6Zv84dHQIGhTUSHLOYx_racMRtCToquXRJJy0rQ',
#      'width': 3036}],
#    'place_id': 'ChIJyw-jRdS6j4ARgub3WeaYpQI',
#    'plus_code': {'compound_code': 'CRFH+PM Stanford, California, United States',
#     'global_code': '849VCRFH+PM'},
#    'price_level': 2,
#    'rating': 3.9,
#    'reference': 'ChIJyw-jRdS6j4ARgub3WeaYpQI',
#    'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 261},
#   {'formatted_address': '325 Sharon Park Dr F1, Menlo Park, CA 94025, United States',
#    'geometry': {'location': {'lat': 37.423559, 'lng': -122.197717},
#     'viewport': {'northeast': {'lat': 37.42494517989272,
#       'lng': -122.1962963701073},
#      'southwest': {'lat': 37.42224552010728, 'lng': -122.1989960298927}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': '56440445ec109f3e5e5a3cef384939993918fccc',
#    'name': 'Starbucks',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 5312,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111525121447495858392/photos">Aisha A</a>'],
#      'photo_reference': 'CmRaAAAA2YWUJjLx-72kz8CDEOyQydTn_rKzhgAhbq1ayFqfW4yVWCT1Wje3Aeu3DGk996wloD8JdyxKECCIbftF9SVef1s3Z5g1jm9BO9qx1eTQnm05GqjyLmQbPOez9gnaP8jOEhDNCyDCFb-gjtSFaBDb1RG5GhTu2KqOZ3PqnQ7UEHsUgRcyMH3uLw',
#      'width': 2988}],
#    'place_id': 'ChIJPd8zEN6kj4ARNd9OfWmHyaU',
#    'plus_code': {'compound_code': 'CRF2+CW Menlo Park, California, United States',
#     'global_code': '849VCRF2+CW'},
#    'price_level': 2,
#    'rating': 4.1,
#    'reference': 'ChIJPd8zEN6kj4ARNd9OfWmHyaU',
#    'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 215},
#   {'formatted_address': '2575 Sand Hill Rd Building #047, Menlo Park, CA 94025, United States',
#    'geometry': {'location': {'lat': 37.4197121, 'lng': -122.2027247},
#     'viewport': {'northeast': {'lat': 37.42109017989272,
#       'lng': -122.2013621201073},
#      'southwest': {'lat': 37.41839052010728, 'lng': -122.2040617798928}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': 'd48186f2b8258ec2a0cf0a9d29d11bef099a5fe9',
#    'name': 'Starbucks',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 289,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111482644130207214700/photos">Starbucks</a>'],
#      'photo_reference': 'CmRaAAAAIZo4-2YL9K_2QtD5kGQgoJigcvql5EzHK7VKxo6s-zTi7FXXGnf-fDQb4iGPXCWpsaHVQa0wZBan4q_8hCl-yy4VA7jhw5D7hPGhW0ZLvKJv4OGiZoMOh93OwT5MRdl5EhDqy6HL9rDuvnpaW5VfAXyCGhTqdjdgf5r0nOHJKbE-WwzN3VcvVQ',
#      'width': 512}],
#    'place_id': 'ChIJzyr7huGkj4AREeGzIIhtLQo',
#    'plus_code': {'compound_code': 'CQ9W+VW Menlo Park, California, United States',
#     'global_code': '849VCQ9W+VW'},
#    'price_level': 2,
#    'rating': 4.1,
#    'reference': 'ChIJzyr7huGkj4AREeGzIIhtLQo',
#    'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#    'user_ratings_total': 23}],
#  'status': 'OK'}
