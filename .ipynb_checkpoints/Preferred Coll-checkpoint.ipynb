# %%
import pandas as pd
import json
import folium
from folium.plugins import MarkerCluster
from pymongo import MongoClient
#from function import connectCollection NameError: name "MongoClient" is not defined

# %%
def connectCollection(database, collection):
    client = MongoClient()
    db = client[database]
    coll = db[collection]
    return db, coll

# %%
db, coll = connectCollection('companies','preferred')

# %%
compas = list(coll.find({'category':'games_video'}))

# %%
print(len(compas))
# Out:
# 414

# %%
print(compas[0])
# Out:
# {'_id': ObjectId('5dd05cc6754df22b96b8c72d'), 'Id': '52cdef7c4bab8bd675297dab', 'name': 'Kyte', 'category': 'games_video', 'description': 'Online & Mobile Video Platform', 'long': -122.409173, 'year': 2006, 'money_raised': '$23.4M', 'location': {'type': 'Point', 'coordinates': [-122.409173, 37.788482]}}

# %%
compas[0]['location']['coordinates']
# Out:
# [-122.409173, 37.788482]

# %%
def getcoord(comp):
    location=comp['location']['coordinates']
    return location

# %%
getcoord(compas[0])
# Out:
# [-122.409173, 37.788482]

# %%
listin=[]
for company in compas:
    listin.append(getcoord(company))

# %%
listin
# Out:
# [[-122.409173, 37.788482],
#  [-117.20834, 32.902266],
#  [34.851612, 31.046051],
#  [-74.0094471, 40.7464969],
#  [-74.3372, 40.801358],
#  [-73.99873, 40.722655],
#  [-122.426804, 37.627971],
#  [-73.995625, 40.726155],
#  [-122.393913, 37.780716],
#  [-122.388243, 37.757758],
#  [-122.137444, 37.421621],
#  [-122.341715, 37.590339],
#  [-122.395089, 37.793819],
#  [-122.206893, 37.484619],
#  [-122.323408, 47.615313],
#  [-122.400558, 37.788668],
#  [-122.2262606, 37.4858654],
#  [-122.154176, 37.408256],
#  [-118.401579, 34.017506],
#  [-122.356756, 47.61968],
#  [-95.712891, 37.09024],
#  [34.851612, 31.046051],
#  [-122.159928, 37.437328],
#  [-122.401245, 37.786942],
#  [-95.712891, 37.09024],
#  [-122.392142, 37.782263],
#  [-122.265869, 37.524422],
#  [-118.453218, 34.017373],
#  [-80.157296, 26.207024],
#  [-122.151158, 47.597965],
#  [-71.058768, 42.350274],
#  [-118.49863, 34.0184659],
#  [-79.348037, 43.799511],
#  [-122.393229, 37.781265],
#  [-93.4094629, 44.865243],
# ...

# %%
print(len(listin))
# Out:
# 414

# %%
map1 = folium.Map(location=[38.9, -77.05], tiles='Stamen Terrain', zoom_start=3)

marker_cluster = MarkerCluster().add_to(map1)

for cia in compas:
    folium.Marker(cia['location']['coordinates'][::-1],
                    radius=2,
                    icon=folium.Icon(icon='cloud',color='red')).add_to(marker_cluster)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_city=folium.Map(location=[40.7221,-73.9712], zoom_start=12)
for wendy in manhattanWendys:
    folium.Marker(wendy['location']['coordinates'][::-1],
                    radius=2,
                    icon=folium.Icon(icon='cloud',color='red'), 
                   ).add_to(map_city)
map2 = folium.Map(location=[38.9, -77.05], tiles='CartoDB dark_matter', zoom_start=11)

marker_cluster = folium.MarkerCluster().add_to(map2)

for point in range(0, len(locationlist)):
    folium.Marker(locationlist[point], popup=df_counters['Name'][point]).add_to(marker_cluster)
map2

# %%
Stamen Terrain

# %%
'''
def getLocation(comp):
    longitude = comp["long"]
    latitude = comp["lat"]
    loc=({
        'type':'Point',
        'coordinates':[longitude,latitude]
    })
    return loc

# %%
for company in compas:
    value = {"$set": {'location':getLocation(company)}}
    coll.update_one(company,value)

# %%
'''
for company in compas:
    value = {"$unset": {'long':''}}
    coll.update_one(company,value)   
'''

# %%
'''
for company in compas:
    value = {"$unset": {'lat':''}}
    coll.update_one(company,value) 
'''

# %%
map_city=folium.Map(location=[37.09024,-95.712891], zoom_start=4)
for cia in UScompanies:
    folium.Marker(cia['location']['coordinates'][::-1],
                    radius=2,
                    icon=folium.Icon(icon='cloud',color='red'), 
                   ).add_to(map_city)

# %% [markdown]
# # MAPA
